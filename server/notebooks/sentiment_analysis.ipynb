# %% [markdown]
# ### Test Loading the TorchScript Model

# %%
import torch
import pandas as pd

# %%
model_path = "sentiment_rnn.pt"
model = torch.jit.load(model_path, map_location=torch.device('cpu'))
model.eval()
# Out:
# RecursiveScriptModule(
#   original_name=SentimentRNN
#   (embedding): RecursiveScriptModule(original_name=Embedding)
#   (lstm): RecursiveScriptModule(original_name=LSTM)
#   (dropout): RecursiveScriptModule(original_name=Dropout)
#   (fc): RecursiveScriptModule(original_name=Linear)
#   (sig): RecursiveScriptModule(original_name=Sigmoid)
# )

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
from string import punctuation
import re
from sklearn.model_selection import train_test_split
from collections import Counter
import nltk
nltk.download('stopwords')

def remove_punc(text):
    text = text.lower()
    return ("".join(i for i in text if i not in punctuation))

data["review"] = data["review"].apply(remove_punc)
print(data.head())
X = data["review"].values
y = data["sentiment"].values
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y)
print(X_train.shape)
print(X_test.shape)

def process(string):
    string = re.sub(r"[^\w\s]", '', string)
    string = re.sub(r"\d", '', string)
    string = re.sub(r"\s+", '', string)
    return string

def tokenize(X_train,y_train,X_test,y_test):
    words = []
    stop_words = set(stopwords.words('english')) 
    for x in X_train:
        for word in x.split():
            word = process(word)
            if word not in stop_words and word != '':
                words.append(word)
                
    counts = Counter(words)
    vocab = sorted(counts, key=counts.get, reverse=True)[:1000]
    vocab_to_int = {word: ii for ii, word in enumerate(vocab,1)}
    new_X_train = []
    new_X_test = []
    for s in X_train:
            new_X_train.append([vocab_to_int[process(word)] for word in s.split() 
                                     if process(word) in vocab_to_int.keys()])
    for s in X_test:
            new_X_test.append([vocab_to_int[process(word)] for word in s.split() 
                                    if process(word) in vocab_to_int.keys()])
            
    new_y_train = [1 if label =='positive' else 0 for label in y_train]  
    new_y_test = [1 if label =='positive' else 0 for label in y_test]
    return new_X_train, new_y_train,new_X_test, new_y_test, vocab_to_int

X_train,y_train,X_test,y_test,vocab_to_int = tokenize(X_train,y_train,X_test,y_test)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/edbertwidjaja/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production br br the filmin...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive
# (37500,)
# (12500,)

# %%
def padding(sentence, seqLength):
    #determine shape
    features = np.zeros((len(sentence), seqLength), dtype=int)
    for i, row in enumerate(sentence):
        if len(row) != 0:
            features[i, -len(row):] = np.array(row)[:seqLength]
    return features

# %%
import numpy as np

def init_hidden(batch_size, device='cpu'):
    hidden_dim = 256 
    num_layers = 2    
    
    return (
        torch.zeros(num_layers, batch_size, hidden_dim).to(device),
        torch.zeros(num_layers, batch_size, hidden_dim).to(device)
    )
    
def tokenize_review(test_review):
    test_review = test_review.lower()
    test_text = ''.join([i for i in test_review if i not in punctuation])
    test_words = test_text.split()
    test_ints = []
    test_ints.append([vocab_to_int.get(word, 0) for word in test_words])
    return test_ints

def predict(net, test_review, sequence_length=500):
    model.eval()
    test_ints = tokenize_review(test_review)
    seq_length=sequence_length
    features = padding(test_ints, seq_length)
    feature_tensor = torch.from_numpy(features)
    batch_size = feature_tensor.size(0)
    h = init_hidden(batch_size)
    with torch.no_grad():
        output, h= model(feature_tensor,h)
    #print('Prediction value: {:.6f}'.format(output.item()))
    if(output.item() > 0.5):
        print("Positive market sentiment detected! With probability of:",output.item())
    else:
        print("Negative market sentiment detected! With probability of:", (1 - output.item()))
        
test_review = 'The worst movie I have seen; acting was terrible and I want my money back. This movie had bad acting and the dialogue was slow.'
predict(model, test_review, 500)
# Out:
# Negative market sentiment detected! With probability of: 0.674791008234024

# %%
import finnhub
from dotenv import load_dotenv
import os
from datetime import datetime
from dateutil.relativedelta import relativedelta

load_dotenv()

current_date = datetime.today()
start_date = current_date - relativedelta(months=1)
finnhub_client = finnhub.Client(api_key=os.getenv("FINNHUB_API_KEY"))
ALL_NEWS = finnhub_client.company_news('NVDA', _from=start_date.strftime('%Y-%m-%d'), to=current_date.strftime('%Y-%m-%d'))

# %%
all_text = []
for news in ALL_NEWS:
    text = news['headline'] + " " + news['summary']
    all_text.append(text)
    
for text in all_text:
    print("Text:", text)
    predict(model, text, 500)
    print("\n")
# Out:
# Text: What Nvidia's Jensen Huang and OpenAI's Sam Altman Had to Say This Week About AI and Jobs Nvidia CEO Jensen Huang said this week he expects “everybody’s jobs will be changed" by artificial intelligence.
# Prediction value: 0.717717
# Positive review detected! With probability of: 0.7177172303199768
#
#
# Text: Intel: Even A Giant Leap Of Faith May Not Be Enough Intel's turnaround under CEO Tan faces major structural, technological, and competitive hurdles. Read more on the INTC stock and if there are any prospects for a turnaround.
# Prediction value: 0.717692
# Positive review detected! With probability of: 0.7176918983459473
#
#
# Text: Should You Forget Nvidia and Buy These 2 Artificial Intelligence (AI) Stocks Instead? Nvidia is the king of AI accelerator chips, but some smaller AI players may have more upside.  AMD has a big opportunity as the AI inference market grows.  Broadcom has big opportunities in networking, custom AI chips, and virtualization.
# Prediction value: 0.717600
# Positive review detected! With probability of: 0.7175998687744141
#
#
# Text: Can Nvidia Stock Double in 5 Years? Nvidia has an extremely high percentage of the market for artificial intelligence (AI) chips.  Nvidia (NASDAQ: NVDA) has delivered extreme wealth for early investors, but it's also rewarded investors who bought shares fairly recently.  Buying Nvidia stock today would be a no-brainer for anyone who thinks it can replicate that success.
# Prediction value: 0.705118
# Positive review detected! With probability of: 0.7051181793212891
#
#
# Text: Prediction: 3 Non-Tech Stocks That Can Blow Past Nvidia's Market Cap by 2035 History suggests three time-tested, industry-leading, brand-name businesses are going to be worth more than artificial intelligence (AI) titan Nvidia 10 years from now.
# Prediction value: 0.738175
# Positive review detected! With probability of: 0.7381753921508789
#
#
# Text: Harbor Human Capital Factor US Large Cap ETF Q1 2025 Commentary During the first quarter, the Harbor Human Capital Factor US Large Cap ETF returned -4.13%, slightly underperforming its benchmark.
# Prediction value: 0.718941
# Positive review detected! With probability of: 0.7189409732818604
#
#
# Text: Dow Jones Futures: Israel-Iran Attacks Hit Market; The Next AI Winners After Nvidia, Broadcom? Israel-Iran fears hit the stock market Friday. Will these AI hardware stocks follow Nvidia, Broadcom higher?
# Prediction value: 0.715813
# Positive review detected! With probability of: 0.7158126831054688
#
#
# Text: Samsung, Nvidia, and SoftBank Just Made a $4.5B Robot Bet--Here's What It Means for the Future of AI Big Tech's latest moonshot isn't software--it's humanoid robots. And they're throwing serious money behind it.
# Prediction value: 0.151948
# Negative review detected! With probability of: 0.8480518609285355
#
#
# Text: Google Search Is Fading. The Whole Internet Could Go With It. The lifeblood of the internet is drying up. What the decline of search means for users, companies, and stocks.
# Prediction value: 0.724327
# Positive review detected! With probability of: 0.7243273854255676
#
#
# Text: Why Shares of D-Wave Quantum Are Sinking This Week Nvidia's CEO Jensen Huang commented on quantum computing this week.  While the quantum computing sector experienced some good news this week, D-Wave also announced an at-the-market (ATM) stock offering to potentially raise new capital.  In a filing with the Securities and Exchange Commission( SEC), D-Wave also said that cash balances on hand as of March 31 are enough "to fund the company to profitability."
# Prediction value: 0.720354
# Positive review detected! With probability of: 0.720354437828064
#
#
# Text: Broadcom Has Quietly Become a Top Tech Stock. AI Chips Are Driving Its Growth. The company has climbed to No. 7 in market value and is just behind Nvidia in AI chips. The source of its growth? Leading-edge AI chips for specific applications.
# Prediction value: 0.717754
# Positive review detected! With probability of: 0.7177535891532898
#
#
# Text: Nvidia: All-Time High Is In Sight, Upgrade To Strong Buy Nvidia Corporation's strong EPS growth, robust fundamentals, and AI-driven demand make it a compelling buy. Click for why I am upgrading NVDA to Strong Buy.
# Prediction value: 0.131496
# Negative review detected! With probability of: 0.868503525853157
#
#
# Text: Nvidia GTC Paris is ’another bullish proof point’ long term - Morgan Stanley Investing.com -- Nvidia’s GTC conference in Paris offered no stock-moving announcements but added further evidence of long-term growth, Morgan Stanley said in a note this week, calling it “another bullish proof point for Nvidia’s business beyond 2025.”
# Prediction value: 0.720099
# Positive review detected! With probability of: 0.720098614692688
#
#
# Text: Why Quantum Computing Stock Is Skyrocketing This Week Jensen Huang's comment that quantum technology was reaching an "inflection point" sent the company's stock flying.  Just months ago, Huang stated he thought the technology was 15 years or more away from maturation.  Shares of Quantum Computing (NASDAQ: QUBT) are surging this week, up 24.2% as of 1:22 p.m. ET.
# Prediction value: 0.717754
# Positive review detected! With probability of: 0.7177536487579346
#
#
# Text: Nvidia is nixing China from its financial forecasts because U.S. restrictions on chip sales have tightened so much, Jensen Huang says The chip executive is “10% politician, 90% CEO,” Wedbush analyst Dan Ives said. “He needs to be cautious on their financial guidance, given the China variable.”
# Prediction value: 0.699976
# Positive review detected! With probability of: 0.6999759078025818
#
#
# Text: NVIDIA (NasdaqGS:NVDA) Ventures Into Autonomous Driving And Consumer Robotics Easyrain has made a significant move by partnering with NVIDIA (NasdaqGS:NVDA) to advance its road detection technologies. Additionally, NVIDIA's ongoing investment in Skild AI reflects its interest in the burgeoning consumer robotics sector. Over the past quarter, NVIDIA's shares rose 19%, which coincides with notable corporate activities, including robust earnings growth and strategic alliances. Amidst a market impacted by geopolitical tensions, such as the Israel-Iran conflict, which...
# Prediction value: 0.717757
# Positive review detected! With probability of: 0.7177571058273315
#
#
# Text: IYY Vs. IWB: Fast Facts On Two Top 1000 ETFs IYY and IWB are two similar large and mid-cap ETFs, holding about 1,000 of the largest US-traded companies. Read the full comparison of the stocks here.
# Prediction value: 0.710939
# Positive review detected! With probability of: 0.7109385132789612
#
#
# Text: Cisco: Tactical Buy For Me, Maybe Not For You (Rating Upgrade)
# Prediction value: 0.653819
# Positive review detected! With probability of: 0.6538193225860596
#
#
# Text: Advanced Micro Devices Sets Sights on Nvidia in AI Race AMD has spent years—and billions of dollars—advancing its capabilities and software to better compete with Nvidia, analysts said.
# Prediction value: 0.562828
# Positive review detected! With probability of: 0.5628283619880676
#
#
# Text: Nvidia, Amazon, Google Lead Tech Selloff After Israel Strikes Iran Wall Street Reacts to Iran-Israel Strikes: Nasdaq Sinks, Tech Feels the Heat
# Prediction value: 0.718390
# Positive review detected! With probability of: 0.7183896899223328
#
#
# Text: Nvidia (NVDA) Expands in Europe With New Sovereign AI Model Partnership Company teams with regional cloud providers, launches Europe-specific LLMs via Nemotron
# Prediction value: 0.717641
# Positive review detected! With probability of: 0.7176409959793091
#
#
# Text: Nvidia to exclude China from its revenue and profit forecasts Nvidia CEO Jensen Huang said he isn't confident that the U.S. will change its mind on chip export restrictions anytime soon.
# Prediction value: 0.839908
# Positive review detected! With probability of: 0.8399081826210022
#
#
# Text: AMD launches M1350 chips, Chime post-IPO: Trending Tickers Advanced Micro Devices (AMD) launches its new M1350 semiconductor, positioned to rival Nvidia's (NVDA) Blackwell line of AI chips. Shares of Chime Financial (CHYM) are stumbling Friday morning, its first full trading day since making its public debut via an IPO on Thursday. Catch Yahoo Finance's full interview with Chime CFO Matt Newcomb, where he discusses what separates fintech companies from banks. To watch more expert insights and analysis on the latest market action, check out more Wealth here.
# Prediction value: 0.713846
# Positive review detected! With probability of: 0.7138455510139465
#
#
# Text: IPO Mania: A Closer Look at Circle and CoreWeave IPO activity post-pandemic has fluctuated significantly. But the tide has shifted positively over the last year, with exciting companies such as NVIDIA-backed CoreWeave and Circle debuting. What should investors know about the two?
# Prediction value: 0.613924
# Positive review detected! With probability of: 0.6139242649078369
#
#
# Text: The Deficit Narrative May Find Its Cure In Artificial Intelligence In this post, we will discuss the âdeficit narrative,â the likely outcomes, and why the cure for the deficit may be found in Artificial Intelligence.
# Prediction value: 0.716555
# Positive review detected! With probability of: 0.7165549993515015
#
#
# Text: Nvidia Stock Falls. What’s Behind the Latest Drop. Nvidia  stock fell early Friday, mirroring losses in the broader market.  CEO Jensen Huang this week announced a flurry of initiatives during his European tour that could strengthen the chip maker’s position in the long run.  Shares dropped 1.3% to $143.15 in early trading Friday, while the  Nasdaq Composite  and  indexes fell 0.8% and 0.7%, respectively, after Israel launched a wide-ranging attack on Iran overnight, putting investors in a risk-off mode.
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177625298500061
#
#
# Text: Nvidia (NVDA) CEO Warns Huawei Will Dominate China If U.S. Keeps AI Chip Curbs Jensen Huang says losing China's developers risks global dominance of China's AI stack
# Prediction value: 0.717541
# Positive review detected! With probability of: 0.7175414562225342
#
#
# Text: AMD (AMD) Unveils 1,400W MI355X AI GPU to Challenge Nvidia's Blackwell New chip targets AI inference with 20.1 PFLOPS, liquid cooling standard
# Prediction value: 0.717634
# Positive review detected! With probability of: 0.7176342010498047
#
#
# Text: Chinese Firms Skirt Chip Curbs by Flying Hard Drives Abroad The U.S. has tightened the noose around the sale of high-end AI chips and other technology to China. Yet Chinese companies have made advances using workarounds. In some cases, AI developers carry data to countries where Nvidia chips are available, frustrating Washington's efforts:  Embed Layers of intermediaries typically separate the Chinese users of American AI chips from the U.
# Prediction value: 0.717507
# Positive review detected! With probability of: 0.7175071835517883
#
#
# Text: Nvidia: Flattening Growth Curve Brings A Rare Window Of Entry (Upgrade) Nvidia Corporation's dominance in AI and strong profitability make it a cautious buy despite slowing growth and China-related risks. Click for our NVDA update.
# Prediction value: 0.717338
# Positive review detected! With probability of: 0.7173382639884949
#
#
# Text: This Week In AI Chips - AMD Advances AI Innovation With Open Ecosystem Approach AMD recently showcased its vision for an open AI ecosystem, emphasizing a collaborative approach through new silicon, software, and systems at its Advancing AI 2025 event. The company introduced the Instinct MI350 series of GPUs, highlighting significant advancements in AI compute performance, efficiency, and scalability. AMD has continued to expand its ROCm open software stack and unveiled its next-generation AI rack designs, aiming for leadership in rack-scale AI performance beyond 2027...
# Prediction value: 0.669606
# Positive review detected! With probability of: 0.6696061491966248
#
#
# Text: Prediction: This Company Will Be the Most Valuable AI Stock in 2026 Microsoft successfully integrated advanced AI technologies across its entire ecosystem.  The company is a dominant player in the enterprise software space, which is relatively resilient to economic conditions.  Microsoft has a diversified revenue business, which helps it face market volatility and competitive pressures.
# Prediction value: 0.716015
# Positive review detected! With probability of: 0.7160148620605469
#
#
# Text: Social Buzz: Wallstreetbets Stocks Decline Pre-Bell Friday; Tesla, Nvidia to Open Lower The most-talked-about stocks in the Reddit subforum Wallstreetbets were declining hours before Frida
# Prediction value: 0.714039
# Positive review detected! With probability of: 0.7140392065048218
#
#
# Text: AMD turns to AI startups to inform chip, software design SAN JOSE (Reuters) -Advanced Micro Devices has forged close ties to a batch of artificial intelligence startups as part of the company's effort to bolster its software and forge superior chip designs.  As AI companies seek alternatives to Nvidia's chips, AMD has begun to expand its plans to build a viable competing line of hardware, acquiring companies such as server maker ZT Systems in its quest to achieve that goal.  But to build a successful line of chips also requires a powerful set of software to efficiently run the programs built by AI developers.
# Prediction value: 0.716699
# Positive review detected! With probability of: 0.7166986465454102
#
#
# Text: Nvidia, Deutsche Telekom Partner to Build Germany's First Industrial AI Cloud Nvidia (NVDA) said Friday it is working with Deutsche Telekom to establish Germany's first industria
# Prediction value: 0.709372
# Positive review detected! With probability of: 0.7093720436096191
#
#
# Text: Warren Buffett Says Buy This Index Fund, and Here's How It Could Turn $500 Per Month Into $1 Million Warren Buffett's incredible stock-picking ability has propelled Berkshire Hathaway to market-beating returns for six decades.  You don't need to be as skilled as Buffett to succeed in the stock market, because simple index funds can deliver spectacular long-term returns.  Warren Buffett is the CEO of the Berkshire Hathaway holding company, where he oversees a number of wholly owned subsidiaries and a $281 billion portfolio of publicly traded stocks and securities.
# Prediction value: 0.717742
# Positive review detected! With probability of: 0.7177422642707825
#
#
# Text: The 2025 stock market rally is about more than just the 'Magnificent 7': Morning Brief After two years of few S&P 500 companies outperforming the index,  market participation is broadening in 2025.
# Prediction value: 0.717737
# Positive review detected! With probability of: 0.7177371978759766
#
#
# Text: Want Exposure to Nvidia, Microsoft, and Tesla? This New ETF Covers Them All. Wedbush tech analyst Dan Ives oversees the ETF that bears his name.  Exchange-traded funds (ETFs) are a great way to gain exposure to the hot field of artificial intelligence (AI).  A new AI ETF emerged recently, and what makes this one stand out is that it's overseen by Dan Ives, the global head of technology research at Wall Street firm Wedbush Fund Advisors.
# Prediction value: 0.714751
# Positive review detected! With probability of: 0.7147510647773743
#
#
# Text: AMD: AI Day Isn't The Reason To Buy, But Server CPU Is (Rating Upgrade)
# Prediction value: 0.651116
# Positive review detected! With probability of: 0.6511157155036926
#
#
# Text: Deutsche Telekom, Nvidia join forces on manufacturers' AI cloud in Germany BERLIN (Reuters) -Deutsche Telekom will join forces with Nvidia to establish an artificial intelligence cloud for European manufacturers in Germany, the companies said on Friday.  Nvidia will supply 10,000 chips, or graphics processing units (GPUs), to be built into Deutsche Telekom's existing data centres.  The cloud, which the companies aim to implement by 2026, is seen as an important stepping stone towards the construction of large-scale data centres, a crucial part of the new German government's drive to modernise the country's lagging industry and part of EU efforts to catch up with other world powers on AI.
# Prediction value: 0.720296
# Positive review detected! With probability of: 0.7202957272529602
#
#
# Text: The Zacks Analyst Blog Highlights NVIDIA, D-Wave Quantum IonQ, QTUM and Lockheed Martin NVDA's CEO sees a quantum leap ahead boosting optimism and momentum for Buy-rated stocks QBTS and IONQ.
# Prediction value: 0.717755
# Positive review detected! With probability of: 0.7177554965019226
#
#
# Text: Microsoft Hits an All-Time High. Here's Why These 2 "Magnificent Seven" Stocks Could Be Next. Paying a reasonable price for a quality company is better than paying a dirt-cheap price for a poor business.  A strong balance sheet can make a big difference during challenging times.  Microsoft (NASDAQ: MSFT) hit a new all-time high early on Wednesday -- making it the only company at the moment valued at a market cap over $3.5 trillion.
# Prediction value: 0.717430
# Positive review detected! With probability of: 0.7174296379089355
#
#
# Text: 5 No-Brainer Artificial intelligence (AI) Stocks to Buy Right Now Palantir is quickly becoming one of the biggest artificial intelligence (AI) winners.  Nvidia, AMD, and TSMC are all set up to be big AI infrastructure spending beneficiaries.  Alphabet has a lot of potential levers it can pull to drive growth.
# Prediction value: 0.717548
# Positive review detected! With probability of: 0.7175479531288147
#
#
# Text: Zacks Investment Ideas feature highlights: Nvidia, Taiwan Semiconductor and Vertiv NVDA, TSM and VRT are powering the AI boom with strong growth and surprisingly reasonable valuations.
# Prediction value: 0.716541
# Positive review detected! With probability of: 0.7165414690971375
#
#
# Text: Stock Market Today: Dow Jones Dives 400 Points As Israel Attacks Iran; Nvidia, Tesla Sell Off (Live Coverage) Stock Market Today: Dow Jones Dives 400 Points As Israel Attacks Iran; Nvidia, Tesla Sell Off (Live Coverage)
# Prediction value: 0.829349
# Positive review detected! With probability of: 0.829349160194397
#
#
# Text: 2 Brilliant Growth Stocks to Buy Now and Hold for the Long Term Momentum continues for Nvidia's data center business as other opportunities emerge for its GPU technology.  Alphabet stock is trading at its most attractive valuation in a long time.  Growth stocks can be some of the best tools an investor has to build wealth for retirement.
# Prediction value: 0.717626
# Positive review detected! With probability of: 0.71762615442276
#
#
# Text: Is CoreWeave a Buy? CoreWeave stock has soared more than 280% since its recent initial public offering.  The company’s revenue has skyrocketed -- but CoreWeave must continue to invest heavily to keep up with artificial intelligence demand.  Nvidia holds a 7% stake in this AI player.
# Prediction value: 0.717739
# Positive review detected! With probability of: 0.7177391052246094
#
#
# Text: 2 Popular AI Stocks to Sell Before They Drop 30% and 55%, According to Select Wall Street Analysts Shares of Palantir and Nvidia have rocketed higher as artificial intelligence has become a major investment theme , but certain Wall Street analysts think it's time to sell.  Palantir is a recognized leader in artificial intelligence and machine learnings software, but it's also the most expensive software stock on the market by a wide margin.
# Prediction value: 0.717744
# Positive review detected! With probability of: 0.7177441120147705
#
#
# Text: Nvidia excludes China from its forecasts due to US restrictions When asked about the Chinese market, Jensen Huang, CEO of Nvidia, said that the company has now resigned itself to no longer betting on the Middle Kingdom in its results. A new product offering...
# Prediction value: 0.705166
# Positive review detected! With probability of: 0.7051657438278198
#
#
# Text: Deutsche Telekom, Nvidia to build AI cloud for industry in Germany BERLIN -Deutsche Telekom and Nvidia will join forces to build an industrial artificial intelligence cloud for European manufacturers in Germany, the first of its kind, the companies said on Friday. ...
# Prediction value: 0.699818
# Positive review detected! With probability of: 0.6998177766799927
#
#
# Text: NVIDIA CORP : Bernstein reiterates its Buy rating Stacy Rasgon from Bernstein retains his positive opinion on the stock with a Buy rating. The target price is still set at USD 185.
# Prediction value: 0.528175
# Positive review detected! With probability of: 0.528174877166748
#
#
# Text: Impax Ellevate Global Women's Leadership Fund Q1 2025 Commentary During the first quarter, the Global Womenâs Leadership portfolio lagged global developed market equities overall in the period.
# Prediction value: 0.703172
# Positive review detected! With probability of: 0.7031723260879517
#
#
# Text: NCZ: Convertibles Should Be Superior To Traditional Bonds Virtus Convertible & Income Fund II has a high 11.61% yield, inflation protection, and recent outperformance. Read here for an analysis of NCZ CEF.
# Prediction value: 0.715222
# Positive review detected! With probability of: 0.7152218222618103
#
#
# Text: BT CEO hails telecom networks as 'UK's real digital backbone' Allison Kirkby, CEO of BT, highlighted how the company is playing a key role in developing the infrastructure that acts as the 'UK's real digital backbone'.
# Prediction value: 0.721912
# Positive review detected! With probability of: 0.7219117879867554
#
#
# Text: Impax Global Social Leaders Fund Q1 2025 Commentary The fund outperformed the benchmark during the last quarter.
# Prediction value: 0.636793
# Positive review detected! With probability of: 0.6367932558059692
#
#
# Text: Super Micro Computer (SMCI) Debuts the Industry’s Broadest AI Solution Stack for NVIDIA Blackwell Super Micro Computer, Inc. (NASDAQ:SMCI) is one of the 15 AI Stocks Making Waves on Wall Street. On June 11, the company announced an expansion of the industry’s broadest portfolio of solutions designed for NVIDIA Blackwell Architecture to the European market. The 30+ solutions offer the most comprehensive and efficient solution stack for NVIDIA HGX B200, GB200 […]
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177630066871643
#
#
# Text: CrowdStrike (CRWD) Boosts AI Security With NVIDIA—Here’s What It Means CrowdStrike Holdings, Inc. (NASDAQ:CRWD) is one of the 15 AI Stocks Making Waves on Wall Street. On June 11, the company announced that it will be integrating Falcon® Cloud Security with NVIDIA universal LLM NIM microservices and NeMo Safety in order to provide full lifecycle protection for AI and over 100,000 large language models (LLMs) in collaboration […]
# Prediction value: 0.718596
# Positive review detected! With probability of: 0.7185959219932556
#
#
# Text: Europe is Getting Its First Industrial AI Cloud—Thanks to NVIDIA (NVDA) NVIDIA Corporation (NASDAQ:NVDA) is one of the 15 AI Stocks Making Waves on Wall Street. On June 11, the company announced that it is building the world’s first industrial AI cloud for European manufacturers at the NVIDIA GTC Paris. Featuring 10,000 GPUs, the AI factory will empower Europe’s industrial leaders to accelerate every manufacturing application, from design, […]
# Prediction value: 0.719262
# Positive review detected! With probability of: 0.7192624807357788
#
#
# Text: Chinese AI Companies Dodge U.S. Chip Curbs by Flying Suitcases of Hard Drives Abroad Engineers carried data to countries where Nvidia chips are available, frustrating Washington’s efforts to restrict China’s access to the technology.
# Prediction value: 0.717761
# Positive review detected! With probability of: 0.7177605628967285
#
#
# Text: Impax Global Environmental Markets Fund Q1 2025 Commentary The Fund's returns declined during the first quarter and slightly underperformed its primary benchmark, the MSCI ACWI.
# Prediction value: 0.717433
# Positive review detected! With probability of: 0.7174328565597534
#
#
# Text: Are Robots The Answer To China's Aged Care Crisis? Beijing Launches Massive Trial To Test If Machines Can Cook, Clean And Console The Elderly Are robots the solution to China's growing aged care problem? The Chinese Ministry of Industry and Information Technology has announced a large-scale trial program to test whether intelligent machines can provide not just physical assistance, but also emotional support for its expanding senior population. What Happened: The ministry has invited private companies with proven track records in elder care to apply for the initiative. Firms must have robust environmental, credit, and safety records t
# Prediction value: 0.717626
# Positive review detected! With probability of: 0.7176259160041809
#
#
# Text: AMD Says New Chips Can Top Nvidia’s in Booming AI Chip Field (Bloomberg) -- Advanced Micro Devices Inc. Chief Executive Officer Lisa Su said her company’s latest AI processors can challenge Nvidia Corp. chips in a market she now expects to soar past $500 billion in the next three years. Most Read from BloombergShuttered NY College Has Alumni Fighting Over Its FutureTrump’s Military Parade Has Washington Bracing for Tanks and WeaponryNYC Renters Brace for Price Hikes After Broker-Fee BanDo World’s Fairs Still Matter?NY Long Island Rail Service Resumes Afte
# Prediction value: 0.712611
# Positive review detected! With probability of: 0.7126110792160034
#
#
# Text: AMD Bolsters AI Data Center Pitch With Full-Rack Systems Advanced Micro Devices on Thursday announced full-rack AI data center systems to better compete with Nvidia. But AMD stock fell.
# Prediction value: 0.716687
# Positive review detected! With probability of: 0.7166869640350342
#
#
# Text: Oracle Casts A Spell
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177630662918091
#
#
# Text: AMD gains on Nvidia? Lisa Su reveals new chips in heated AI inference race Investing.com -- Advanced Micro Devices Inc (NASDAQ:AMD) made an aggressive bid for dominance in AI inference at its Advancing AI event Thursday, unveiling new chips that directly challenge NVIDIA Corporation’s (NASDAQ:NVDA) supremacy in the data center GPU market. AMD claims its latest Instinct MI355X accelerators surpass Nvidia’s most advanced Blackwell GPUs in inference performance while offering a significant cost advantage, a critical selling point as hyperscalers look to scale generative A
# Prediction value: 0.718707
# Positive review detected! With probability of: 0.7187065482139587
#
#
# Text: Here's Why Shares in Navitas Powered Higher Again This Week A recent presentation by Navitas' management shed some light on the potential of its collobaration with Nvidia.  The next generation of data centers is expected to drive significant growth for many technology companies, including Navitas.  The move comes as investors continue to digest the news that Nvidia is collaborating with Navitas to develop data center architecture for the next generation of data centers, due to launch in 2027.
# Prediction value: 0.719286
# Positive review detected! With probability of: 0.7192862629890442
#
#
# Text: AMD Introduces AI-Focused MI350 Series, Part of ‘Vision for an Open AI’ Ecosystem The chip maker said it partnered with prominent companies such as Meta Platforms, OpenAI, Oracle and Microsoft as it seeks an open AI ecosystem.
# Prediction value: 0.712186
# Positive review detected! With probability of: 0.7121856212615967
#
#
# Text: AMD Drives System-Level AI Advances There was a great deal of focus on the official launch of their Instinct MI350 and higher-wattage, faster performing MI355X GPU-based chips, which AMD had previously announced last year.
# Prediction value: 0.479208
# Negative review detected! With probability of: 0.5207917094230652
#
#
# Text: America's Chip Crackdown Just Handed China a $8B AI Opportunity Arm and Nvidia warn export bans are fueling China's tech ascent and shrinking U.S. market share
# Prediction value: 0.709610
# Positive review detected! With probability of: 0.709609866142273
#
#
# Text: AMD’s efforts to chase Nvidia have fallen flat. Can its new chips help? AMD’s efforts to chase Nvidia have fallen flat. Can its new chips help?
# Prediction value: 0.573719
# Positive review detected! With probability of: 0.5737188458442688
#
#
# Text: Why Buy QBTS & IONQ Stocks After NVIDIA CEO's Remarks? NVDA CEO Jensen Huang's upbeat take on quantum computing sparks investor interest in QBTS and IONQ stocks.
# Prediction value: 0.717501
# Positive review detected! With probability of: 0.7175008058547974
#
#
# Text: Exclusive-'Neocloud' Crusoe to buy $400 million worth of AMD chips for AI data centers SAN FRANCISCO (Reuters) -Crusoe CEO Chase Lochmiller said on Thursday the artificial intelligence data center builder planned to purchase roughly $400 million worth of AI chips from Advanced Micro Devices to add to its portfolio of computing power.  The cloud computing startup is aiming to build a data center - or cluster - to house the AMD AI chips in the U.S. and will rent them to customers for building AI models and running applications.  Crusoe's data centers are purpose-built to house AI chips, which it says allows it to offer superior performance compared with older designs.
# Prediction value: 0.677997
# Positive review detected! With probability of: 0.6779970526695251
#
#
# Text: Nvidia to exclude China from forecasts amid US chip export curbs, CNN reports (Reuters) -Nvidia  will no longer include the China market in its revenue and profit forecasts following stringent U.S. trade restrictions on chip sales to the region, CEO Jensen Huang told CNN on Thursday.  When asked if the United States would lift the export controls after the trade discussions with China in London this week, Huang said he was not counting on it.  Huang reiterated his criticism of U.S. chip export curbs during his CNN interview, building on his earlier remarks about the restrictions from April that prevented Nvidia from selling its H20 chip made for China.
# Prediction value: 0.691744
# Positive review detected! With probability of: 0.691743791103363
#
#
# Text: AMD launches MI350 AI chip line to rival Nvidia's Blackwell processors, debuts AI cloud service AMD launched its MI350 line of AI chips on Thursday.
# Prediction value: 0.717060
# Positive review detected! With probability of: 0.7170597910881042
#
#
# Text: AMD Unveils New AI Chips to Take On Nvidia FEATURE   Advanced Micro Devices is upping its game in the artificial-intelligence infrastructure space. On Thursday, at AMD’s Advancing AI event in San Jose, Calif., the company announced its latest AI chips to compete with Nvidia the market leader: the AMD Instinct MI350 series consisting of the MI350X and MI355X.
# Prediction value: 0.716666
# Positive review detected! With probability of: 0.7166656255722046
#
#
# Text: Nvidia will stop including China in its forecasts amid US chip export controls, CEO says Chipmaker Nvidia will exclude the Chinese market from its revenue and profit forecasts following the imposition of tough US restrictions on chip sales to China, its CEO said Thursday.
# Prediction value: 0.681552
# Positive review detected! With probability of: 0.6815522909164429
#
#
# Text: Micron’s stock is on a hot streak. Can it continue? Micron’s stock is on a hot streak. Can it continue?
# Prediction value: 0.715822
# Positive review detected! With probability of: 0.7158223390579224
#
#
# Text: AMD CEO unveils new AI chips SAN JOSE (Reuters) -Advanced Micro Devices CEO Lisa Su showed off a new crop of artificial intelligence chips that will compete with the flagship processors designed by Nvidia.  AMD shares were roughly flat in early afternoon trading.  Su took the stage to discuss the MI350 series and MI400 series AI chips that she said would compete with Nvidia's Blackwell line of processors.
# Prediction value: 0.711821
# Positive review detected! With probability of: 0.7118205428123474
#
#
# Text: NVIDIA (NasdaqGS:NVDA) Ventures Into AI Robotics, Manufacturing, And Healthcare With Strategic Alliances NVIDIA (NasdaqGS:NVDA) recently announced various initiatives, such as plans to take minority stakes in Skild AI with Samsung and partnerships to enhance AI systems, which may relate to its 24% price increase over the last quarter. The company's M&A rumors, investment in AI and quantum computing, and growing strategic alliances likely added momentum to its share price. Broad market trends, including rising tech stocks and overall market optimism, also supported NVIDIA's upward trajectory,...
# Prediction value: 0.728592
# Positive review detected! With probability of: 0.7285920977592468
#
#
# Text: Nvidia CEO Calls 'New Era' of Autonomous Vehicles and Robots Jensen Huang: Nvidia Will Power the Age of AI Machines and AVs
# Prediction value: 0.713831
# Positive review detected! With probability of: 0.7138305306434631
#
#
# Text: Nvidia, Samsung Back Skild AI's $4.5 Billion Valuation Chip and electronics giants invest $35 million to test adaptive-robotics waters
# Prediction value: 0.717754
# Positive review detected! With probability of: 0.7177537083625793
#
#
# Text: SOXS: Losses Will Only Deepen From Here -- Bad Time To Bet Against Semis Semiconductor stocks have rebounded from April lows with the AI growth story back on track, making SOXS unattractive even after its dip. Read the full SOXS stock analysis here.
# Prediction value: 0.702614
# Positive review detected! With probability of: 0.7026139497756958
#
#
# Text: VRT vs. NVT: Which Data Center Infrastructure Stock Is the Better Buy? Vertiv Holdings and nVent Electric are well-known players in the Data Center Infrastructure market. Let's find out which one is a better investment option.
# Prediction value: 0.683520
# Positive review detected! With probability of: 0.6835203766822815
#
#
# Text: AMD unveils AI server as OpenAI taps its newest chips Advanced Micro DevicesCEO Lisa Su on Thursday unveiled a new artificialintelligence server for 2026 that aims to challenge Nvidia'sflagship offerings as OpenAI's CEO said the ChatGPTcreator would...
# Prediction value: 0.562668
# Positive review detected! With probability of: 0.5626683235168457
#
#
# Text: AMD Stock: Why It's Going Up And Should Continue Going Up New AI accelerators, EPYC's continued dominance, and resurgent desktop CPU sales have Advanced Micro Devices, Inc. set up for success. Click for my AMD update.
# Prediction value: 0.717165
# Positive review detected! With probability of: 0.7171650528907776
#
#
# Text: Cisco Expands AI Portfolio for Data Centers: Why the Stock is a Hold CSCO is benefiting from an expanding security and AI portfolio despite challenging macroeconomic conditions and stretched valuation.
# Prediction value: 0.716906
# Positive review detected! With probability of: 0.7169060707092285
#
#
# Text: Super Micro Unleashes 30+ Nvidia Blackwell AI Systems Across Europe Super Micro Rolls Out Blackwell AI Servers in Europe to Ride AI Boom
# Prediction value: 0.717723
# Positive review detected! With probability of: 0.7177231907844543
#
#
# Text: 'Mag 7' turned 'Mid 7': Is 2025 the end of tech dominance? The tech sector (XLK), specifically the "Magnificent Seven," made up of Nvidia (NVDA), Alphabet (GOOG, GOOGL), Tesla (TSLA), Microsoft (MSFT), Amazon (AMZN), Meta (META), and Apple (AAPL), was a significant driver of market gains in 2023 and 2024. However, 2025 has been a different story so far. Yahoo Finance Markets Reporter Josh Schafer and Wall Street Alliance Group partner Aadil Zaman sit down with Brad Smith on Catalysts to take a look at how the Magnificent Seven has underperformed the wider market in 2025. To watch more expert insights and analysis on the latest market action, check out more Catalysts here.
# Prediction value: 0.713845
# Positive review detected! With probability of: 0.7138445973396301
#
#
# Text: Nvidia to stop including China in forecasts amid US chip export controls, CNN reports Nvidia will exclude theChinese market from its revenue and profit forecasts followingthe imposition of tough U.S. restrictions on chip sales toChina, CEO Jensen Huang told CNN on Thursday. ...
# Prediction value: 0.725921
# Positive review detected! With probability of: 0.7259207367897034
#
#
# Text: US says China's Huawei can't make more than 200,000 AI chips in 2025 China's HuaweiTechnologies is capable of producing no more than200,000 advanced artificial intelligence chips in 2025, a topU.S. exports controls official told lawmakers on Thursday,warning that...
# Prediction value: 0.721285
# Positive review detected! With probability of: 0.7212846279144287
#
#
# Text: Impax Global Opportunities Fund Q1 2025 Commentary The fund underperformed the benchmark during the last quarter.
# Prediction value: 0.636878
# Positive review detected! With probability of: 0.6368777751922607
#
#
# Text: 'Neocloud' Crusoe to buy $400 million worth of AMD chips for AI data centers Crusoe CEO ChaseLochmiller said on Thursday the artificial intelligence datacenter builder planned to purchase roughly $400 million worth ofAI chips from Advanced Micro Devices to add to...
# Prediction value: 0.689188
# Positive review detected! With probability of: 0.6891876459121704
#
#
# Text: Nvidia CEO Says It Will Stop Including China In Its Forecasts Amid Us Chip Export Controls- CNN NVIDIA Corp: * NVIDIA WILL STOP INCLUDING CHINA IN ITS FORECASTS AMID USCHIPEXPORT CONTROLS, CEO SAYS- CNNSource text: [ID:https://tinyurl.com/mw47csmv]Further company coverage: ...
# Prediction value: 0.714893
# Positive review detected! With probability of: 0.7148932218551636
#
#
# Text: Nebius Expands AI Cloud in Europe With NVIDIA GB200 and Blackwell NBIS expands its AI Cloud with NVIDIA GB200 in Europe, deepening ties with NVIDIA and accelerating sovereign AI innovation.
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177630662918091
#
#
# Text: Nvidia Stock Is Rising. What’s Curbing Its Gains. The AI chip maker's stock was under pressure as trade uncertainty overshadowed CEO Jensen Huang's European tour.
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177630662918091
#
#
# Text: Micron to invest $200 billion in US memory facilities Micron says it's investing an additional $30 billion in US infrastructure as part of its $200 billion manufacturing and R&D buildout.
# Prediction value: 0.717550
# Positive review detected! With probability of: 0.7175500988960266
#
#
# Text: CoreWeave Shorts Face 150% Borrow Costs After $1.6 Billion Loss (Bloomberg) -- CoreWeave Inc.’s soaring share price is torching short sellers who are paying high prices to bet that the stock will soon fall back to earth.Most Read from BloombergShuttered NY College Has Alumni Fighting Over Its FutureTrump’s Military Parade Has Washington Bracing for Tanks and WeaponryNYC Renters Brace for Price Hikes After Broker-Fee BanNY Long Island Rail Service Resumes After Grand Central FireDo World’s Fairs Still Matter?A more than two-fold gain in CoreWeave’s shares sin
# Prediction value: 0.717663
# Positive review detected! With probability of: 0.7176626324653625
#
#
# Text: Nvidia and Samsung Bet Big on AI Robots With $100 Skild Deal Nvidia, Samsung Take Minority Stakes in Skild AI in $100M Series B Round
# Prediction value: 0.700332
# Positive review detected! With probability of: 0.7003323435783386
#
#
# Text: Quantum stocks higher as Nvidia CEO sees ‘inflection point’ Quantum computing technology is at an inflection point, Nvidia (NVDA) CEO Jensen Huang told the VivaTech conference in Paris on Wednesday, adding that quantum computing will solve “some interesting problems” in the coming years, Reuters’ Supantha Mukherjee reported. The comments sound like a change in tone given that months ago Huang had offered his opinion that “very useful” quantum computers are likely decades away. Shares of quantum computing stocks moving higher in early Wednesday trading fo
# Prediction value: 0.714806
# Positive review detected! With probability of: 0.714805543422699
#
#
# Text: Are AI Stocks Overpriced? These 3 Leaders Look Cheap (NVDA, TSM, VRT) Nvidia, Taiwan Semiconductor and Vertiv shares appear to be trading a very reasonable valuations, despite huge stock apprecaition
# Prediction value: 0.686636
# Positive review detected! With probability of: 0.6866362690925598
#
#
# Text: The Zacks Analyst Blog Highlights Intel, NVIDIA, Taiwan Semiconductor Manufacturing and Advanced Micro Devices INTC jumps 10% as new CEO Lip-Bu Tan sparks optimism over AI chips and a potential foundry turnaround in 2025.
# Prediction value: 0.718565
# Positive review detected! With probability of: 0.7185652256011963
#
#
# Text: Arm Holdings: Premium Valuation At Risk With China's RISC-V Gambit And Hardware Pivot China's RISC-V chip growth is challenging Arm's market position. Read more bout ARM's strategy shift and why a 47% downside is anticipated.
# Prediction value: 0.717613
# Positive review detected! With probability of: 0.7176133990287781
#
#
# Text: Sofinnova taps NVIDIA to bolster portfolio companies’ computational power Sofinnova’s partnership with NVIDIA will avail select life science companies in the VC’s portfolio with increased computational speed.
# Prediction value: 0.717654
# Positive review detected! With probability of: 0.7176541686058044
#
#
# Text: Nvidia (NVDA) to Host Virtual Annual Shareholder Meeting on June 25 Shareholders must use their control number to vote and ask questions; guests may also attend by registering.
# Prediction value: 0.769654
# Positive review detected! With probability of: 0.7696539759635925
#
#
# Text: Cisco Stock: Three Reasons To Watch This Nvidia AI Partner And Dot-Com Darling Boosted by demand for data centers and AI partnerships with Nvidia and Microsoft, Cisco stock looks to etch a breakout.
# Prediction value: 0.717328
# Positive review detected! With probability of: 0.7173283696174622
#
#
# Text: Quantum Computing Stocks: Does 'Annealing' Pioneer D-Wave Get Enough Respect? D-Wave has been the best performer among quantum computing stocks in 2025. The company is a leader in annealing quantum technology.
# Prediction value: 0.717391
# Positive review detected! With probability of: 0.7173913717269897
#
#
# Text: Nvidia (NVDA) CEO Signals Quantum Inflection Point Nvidia CEO Jensen Huang said quantum computing is reaching an inflection point.
# Prediction value: 0.694951
# Positive review detected! With probability of: 0.6949508190155029
#
#
# Text: Big Tech stocks like Nvidia, Microsoft help S&P 500 shake off early losses Big Tech stocks like Nvidia, Microsoft help S&P 500 shake off early losses
# Prediction value: 0.707313
# Positive review detected! With probability of: 0.7073128819465637
#
#
# Text: Nvidia to develop industrial AI cloud for manufacturers in Europe The AI factory will include 10,000 GPUs, featuring Nvidia DGX B200 systems and RTX PRO Servers.
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177630662918091
#
#
# Text: Stocks Liked Inflation Data. Why the Optimism Didn’t Last Long. Trump pivots to trade, May inflation is mild, the U.S. wants more nuclear capacity, and more news to start your day.
# Prediction value: 0.664744
# Positive review detected! With probability of: 0.6647436618804932
#
#
# Text: Prediction: Nvidia's Recent Unobtrusive Maneuver Could Signal a Big Growth Move Ahead. Nvidia dominates the artificial intelligence (AI) chip market, which has helped earnings skyrocket.  Nvidia (NASDAQ: NVDA) has seen its earnings and share price soar over the past several years.  This is as it built dominance in one of the world's most-watched hot technologies: artificial intelligence (AI).
# Prediction value: 0.715772
# Positive review detected! With probability of: 0.7157724499702454
#
#
# Text: The AI Bubble: Advanced AI Faces A 'Complete Accuracy Collapse' Discover why Apple Inc.'s study reveals critical challenges in advanced AI models, hinting at a Gen AI bubble burstâand its impact on the S&P. Click for more.
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177627086639404
#
#
# Text: AMD chief executive to unveil new AI chips Advanced MicroDevices CEO Lisa Su is expected to take the stage on Thursday ata company event in San Jose, California, to discuss thecompany's plans for the artificial intelligence chips...
# Prediction value: 0.717730
# Positive review detected! With probability of: 0.7177300453186035
#
#
# Text: Large cryptocurrencies drop on Dogecoin, Sui declines Large cryptocurrencies drop on Dogecoin, Sui declines
# Prediction value: 0.718621
# Positive review detected! With probability of: 0.7186208963394165
#
#
# Text: Could This High-Flying Artificial Intelligence Stock Be the Next Nvidia? Nvidia's high valuation could mean limited returns for investors who buy the stock today.  A more compelling option recently has been to invest in CoreWeave, a recently listed artificial intelligence stock.  Nvidia (NASDAQ: NVDA) is one of the most valuable companies in the world, with a market cap north of $3 trillion.
# Prediction value: 0.717628
# Positive review detected! With probability of: 0.7176284790039062
#
#
# Text: Prediction: 3 Stocks Berkshire Hathaway Will Add to Its Portfolio After Warren Buffett Steps Down as CEO Berkshire could have multiple new holdings as Abel may want to put his stamp on the company.  There are some solid blue-chip stocks that aren't in Berkshire's portfolio that arguably should be in there already.  Next year, Berkshire Hathaway will have a new CEO.
# Prediction value: 0.682881
# Positive review detected! With probability of: 0.6828808188438416
#
#
# Text: Nvidia: Will See You At $100 Soon Once Again (Technical Analysis)
# Prediction value: 0.753265
# Positive review detected! With probability of: 0.753264844417572
#
#
# Text: Nvidia collaborates for sovereign LLMs The models support Europe’s 24 official languages and reflect local languages and cultures.
# Prediction value: 0.725349
# Positive review detected! With probability of: 0.7253487706184387
#
#
# Text: Sizzling Rally in US Stocks Leaves Them Pricey Compared to Bonds (Bloomberg) -- Traders who hung on during this year’s tariff-fueled rollercoaster ride in stocks are facing a conundrum: Bonds may offer more attractive returns in coming years, according to one widely tracked measure. Most Read from BloombergShuttered NY College Has Alumni Fighting Over Its FutureTrump’s Military Parade Has Washington Bracing for Tanks and WeaponryNYC Renters Brace for Price Hikes After Broker-Fee BanNY Long Island Rail Service Resumes After Grand Central FireDo World’s Fairs S
# Prediction value: 0.717555
# Positive review detected! With probability of: 0.7175554633140564
#
#
# Text: Nvidia's CEO Pumped Quantum Computing, But It's A Stock To Avoid Quantum Computing's Q1 FY 2025 showed a significant revenue miss and an EPS beat. Click here to find out why QUBT stock is a Hold.
# Prediction value: 0.740648
# Positive review detected! With probability of: 0.7406480312347412
#
#
# Text: 3 No-Brainer Artificial Intelligence (AI) Stocks That Can Be Suitable Options for Any Investor Nvidia (NASDAQ: NVDA), Microsoft (NASDAQ: MSFT), and Amazon (NASDAQ: AMZN) are big names in tech, and they can also benefit significantly from AI.  Chipmaker Nvidia is simply unstoppable.  If that happens, its growth will take a hit, and investors may opt for other growth stocks instead.
# Prediction value: 0.737618
# Positive review detected! With probability of: 0.7376176714897156
#
#
# Text: Prediction: Nvidia Stock Is Going to Hit $200 in 2025 Nvidia's Blackwell data center chips are the best in the world for processing artificial intelligence (AI) workloads.  New AI reasoning models require significantly more computing capacity than their predecessors, which is fueling incredible demand for chips.  Nvidia stock is trading at an attractive valuation right now, which could set the stage for a rally to $200 before 2025 is over.
# Prediction value: 0.717410
# Positive review detected! With probability of: 0.7174097299575806
#
#
# Text: Micron boosts US investment plan by $30 billion amid Trump's onshoring push Memory chip maker MicronTechnology said on Thursday it is expanding its U.S.investments by $30 billion as President Donald Trump pressescompanies to boost U.S. investments and threatens new tariffs...
# Prediction value: 0.681706
# Positive review detected! With probability of: 0.6817063689231873
#
#
# ...
#
#
# Text: Zacks Investment Ideas feature highlights: NVIDIA, Innodata and Broadcom NVIDIA, Innodata, and Broadcom surge on booming AI demand, with strong earnings and bullish guidance fueling momentum.
# Prediction value: 0.717022
# Positive review detected! With probability of: 0.7170219421386719
#
#
# Text: Nvidia CEO Changes Tune on Quantum Computing. D-Wave, Rigetti, and IonQ Stocks Rise. Jensen Huang says quantum machines will be used to solve ‘interesting problems in the coming years.’
# Prediction value: 0.648538
# Positive review detected! With probability of: 0.6485381126403809
#
#
# Text: AI Chips Update - AI Blueprint Revolutionizes Financial Services With NVIDIA Technology Dataiku has introduced a new FSI Blueprint, aimed at facilitating the deployment of agentic AI systems within the financial services sector. This blueprint, enhanced by NVIDIA's accelerated computing technologies, supports banking and insurance firms in creating and managing intelligent AI agents at scale, while adhering to industry regulations. Leveraging NVIDIA's NIM microservices, NeMo, and GPU infrastructure, the blueprint offers a secure and modular framework suitable for diverse...
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.7177627086639404
#
#
# Text: Nvidia, Perplexity partner with European firms to boost local AI models SAN FRANCISCO (Reuters) -Nvidia and artificial intelligence search firm Perplexity on Wednesday said they are partnering with more than a dozen AI firms in Europe and the Middle East to refine those firms' AI technologies and distribute them to local businesses.  Nvidia said it will work with model makers in France, Germany, Italy, Poland, Spain and Sweden to help make AI models in local languages become what are called reasoning models, which are capable of carrying out more complicated tasks.  AI technologies built in English and Chinese have started to shift to that technology, but that transition is more difficult in languages where less training data is available.
# Prediction value: 0.717536
# Positive review detected! With probability of: 0.7175363302230835
#
#
# Text: Prediction: Nvidia Stock Will Get a Boost From an Increase in Acquisition Activity CFO Colette Kress made statements last December suggesting the company is on the lookout for smart acquisitions.  Nvidia's job ads suggests the company is beefing up its mergers and acquisitions (M&A) capabilities.  Nvidia's mighty balance sheet and massive free cash flow generation give it an advantage over competitors in the acquisition realm.
# Prediction value: 0.717644
# Positive review detected! With probability of: 0.7176440954208374
#
#
# Text: Nvidia and Perplexity Team Up in European AI Push The chip giant and AI search startup are offering specialized AI models for European users, aiming to widen their reach in the region.
# Prediction value: 0.717763
# Positive review detected! With probability of: 0.71776282787323
#
#
# Text: Quantum stocks rise as Nvidia CEO Huang says inflection is near Investing.com -- Shares of several quantum computing companies have risen premarket on Wednesday after Nvidia (NASDAQ:NVDA) CEO Jensen Huang reiterated that quantum technology is at an "inflection point."
# Prediction value: 0.695603
# Positive review detected! With probability of: 0.6956027746200562
#
#
# Text: American Century Ultra Fund Q1 2025 Commentary Large-cap value marked the only U.S. stock category that posted a quarterly gain. Mid-cap stocks broadly outperformed large-cap stocks. Read more here.
# Prediction value: 0.579795
# Positive review detected! With probability of: 0.579794704914093
#
#
# Text: NVIDIA Partners With Novo Nordisk and DCAI to Advance Drug Discovery Leading Global Pharma Joins Danish Enterprises, Startups and Public Health Systems Using AI Factories to Improve Drug Discovery and Healthcare Novo Nordisk / DCAI NVIDIA is collaborating with Novo Nordisk to accelerate drug discovery efforts through innovative AI use cases. PARIS, June 11, 2025 (GLOBE NEWSWIRE) -- NVIDIA GTC Paris at VivaTech — NVIDIA today announced a collaboration with Novo Nordisk to accelerate drug discovery efforts through innovative AI use cases. The work supports Novo Nor
# Prediction value: 0.721398
# Positive review detected! With probability of: 0.7213981747627258
#
#
# Text: AI Bets That Fueled Big Tech’s Surge Now Threaten Rich Profits (Bloomberg) -- Some investors are questioning the amount of cash Big Tech is throwing at artificial intelligence, fueling concerns for profit margins and the risk that depreciation expenses will drag stocks down before companies can see investments pay off. Most Read from BloombergTrump’s Military Parade Has Washington Bracing for Tanks and WeaponryNY Long Island Rail Service Resumes After Grand Central FireNYC Mayoral Candidates All Agree on Building More Housing. But Where?Senator Calls for Cl
# Prediction value: 0.717634
# Positive review detected! With probability of: 0.7176339030265808
#
#
# Text: Nvidia's Generative AI To Fuel Hyper-Scalable 3D Rendering For L'Oréal L’Oréal Groupe announced on Wednesday that it has partnered with Nvidia Corp. (NASDAQ:NVDA) to unlock AI’s potential in multiple aspects of beauty. Through this collaboration, L’Oréal and its partner ecosystem will leverage the Nvidia AI Enterprise platform for rapid development and deployment of AI, like scaling 3D digital rendering of L’Oréal products, for a fusion of physical AI and generative AI, expanding creative possibilities. A company press release said that 3D digital rendering of prod
# Prediction value: 0.715953
# Positive review detected! With probability of: 0.7159528136253357
#
#
# Text: NVIDIA Builds World’s First Industrial AI Cloud to Advance European Manufacturing Europe Industrial AI NVIDIA builds the world’s first industrial AI cloud to enable Europe’s industrial leaders to accelerate manufacturing design, engineering and simulation. NVIDIA to Build NVIDIA DGX B200- and NVIDIA RTX PRO Server-Powered AI Cloud in Germany to Accelerate Industrial Manufacturing ApplicationsIndustrial Software Leaders Ansys, Cadence and Siemens Announce Acceleration With NVIDIA CUDA-X and AI LibrariesFrom Design to Shop Floor Operation, BMW Group, Maserati, Schaeffler and Vo
# Prediction value: 0.715295
# Positive review detected! With probability of: 0.7152948975563049
#
#
# Text: Siemens and NVIDIA Expand Partnership to Accelerate AI Capabilities in Manufacturing Siemens and NVIDIA Siemens and NVIDIA announced an expansion of their partnership to accelerate the next era of industrial AI and digitalization and enable the factory of the future. Companies Celebrate Collaboration Driving Industrial AI for Global ManufacturersExpanded Partnership to Enable AI-Powered Factories of the Future, Connecting NVIDIA AI and Accelerated Computing With the Siemens Xcelerator Platform and ProductsNew Industrial AI Infrastructure on NVIDIA Accelerated Computing Transform
# Prediction value: 0.717761
# Positive review detected! With probability of: 0.7177612781524658
#
#
# Text: Germany's Merz to meet Nvidia CEO on Friday, says German source German Chancellor FriedrichMerz will meet Nvidia CEO Jensen Huang on Friday, aGerman government source told Reuters on Wednesday. Huang said earlier that the company would build its...
# Prediction value: 0.699884
# Positive review detected! With probability of: 0.6998835206031799
#
#
# Text: NVIDIA DGX Cloud Lepton Connects Europe’s Developers to Global NVIDIA Compute Ecosystem NVIDIA DGX Cloud Lepton DGX Cloud Lepton seamlessly connects developers to GPU resources worldwide, empowering them to quickly access, scale and accelerate the next era of AI breakthroughs. Mistral AI, Nebius, Nscale, Firebird, Fluidstack, Hydra Host, Scaleway and Together AI — Along With AWS and Microsoft Azure — Bring Compute Resources to DGX Cloud Lepton Marketplace to Meet AI DemandHugging Face Integrates DGX Cloud Lepton Into Training Cluster as a Service, Expanding AI Researcher Access to
# Prediction value: 0.717738
# Positive review detected! With probability of: 0.7177384495735168
#
#
# Text: Rafay Integrates with NVIDIA Enterprise AI Factory to Deliver Advanced Infrastructure Orchestration and Management Rafay Systems announced its integration in the NVIDIA Enterprise AI Factory validated design, a major initiative intended to accelerate the development of sovereign AI agents and AI factories. NVIDIA...
# Prediction value: 0.717482
# Positive review detected! With probability of: 0.7174818515777588
#
#
# Text: Palantir: 3 Explosive Growth Catalysts To Be Excited About Palantir Technologies Inc. shines with strong financials, AI innovation, and growing contracts. Click for why PLTR is a Buy for long-term investors and my strategy.
# Prediction value: 0.712791
# Positive review detected! With probability of: 0.7127912640571594
#
#
# Text: Most big cryptocurrencies increase as Dogecoin  rallies Most big cryptocurrencies increase as Dogecoin  rallies
# Prediction value: 0.717240
# Positive review detected! With probability of: 0.7172397375106812
#
#
# Text: Broadcom: Never Try To Overplay A Good Hand Broadcom investors are riding high as the stock made a new high last week. Click here to find out why I rate AVGO stock a Hold.
# Prediction value: 0.743616
# Positive review detected! With probability of: 0.7436161637306213
#
#
# Text: Nebius Delivers First NVIDIA Blackwell General Availability in Europe; Brings Nvidia Ai Enterprise to Nebius AI Cloud Nebius announced the first general availability of NVIDIA GB200 Grace Blackwell Superchip capacity for customers in Europe, as it continues to build out full-stack AI infrastructure globally to...
# Prediction value: 0.717760
# Positive review detected! With probability of: 0.7177600264549255
#
#
# Text: Transcript : NVIDIA Corporation - Shareholder/Analyst Call Presenter SpeechColette Kress So thanks for joining us. Jensen and I are here to go through any questions that you've had, both what you've seen today in our Paris GTC, but also we have done
# Prediction value: 0.775103
# Positive review detected! With probability of: 0.7751034498214722
#
#
# Text: SKAI Intelligence To Debut World's First NVIDIA's Omniverse-Based AIGC Solution At VivaTech 2025 SKAI Worldwide Co Ltd: * SKAI INTELLIGENCE TO DEBUT WORLD'S FIRST NVIDIA'SOMNIVERSE-BASED AIGC SOLUTION AT VIVATECH 2025Source text:Further company coverage: ...
# Prediction value: 0.719755
# Positive review detected! With probability of: 0.7197545170783997
#
#
# Text: Stocks Can Break Record Highs  if These Things Go Right. That’s a Big If. Stocks Can Break Record Highs  if These Things Go Right. That’s a Big If.
# Prediction value: 0.703875
# Positive review detected! With probability of: 0.7038754820823669
#
#
# Text: Milestone Revolutionizes Urban Infrastructure and Traffic Systems in Europe With NVIDIA and Nebius Milestone?s Project Hafnia is now engaged in Europe with the city of Genoa, Italy. The aim is to develop AI-driven solutions to enhance traffic management systems and create smarter cities with...
# Prediction value: 0.704900
# Positive review detected! With probability of: 0.7049000859260559
#
#
# Text: Nvidia Stock Rises. Inflation Data Gives Shares a Boost CEO’s Speech Didn’t. Nvidia Stock Rises. Inflation Data Gives Shares a Boost CEO’s Speech Didn’t.
# Prediction value: 0.715549
# Positive review detected! With probability of: 0.7155489325523376
#
#
# Text: Accenture Teams with NVIDIA to Advance AI Agenda for Europe with AI Refinery for Sovereign and Agentic AI Accenture expanded its AI Refinery platform for Europe with new sovereign and agentic capabilities to help European organizations maintain control over critical data and apply innovative AI solutions....
# Prediction value: 0.717712
# Positive review detected! With probability of: 0.7177121043205261
#
#
# Text: Diraq Pty Ltd and Q.M Technologies Ltd. Employ AI for Scaling Silicon-Based Quantum Computers with Nvidia DGX Quantum Diraq and QM Technologies Inc. announced the first-ever tight integration of GPUs and silicon quantum processors with the deployment of a system using the NVIDIA DGX Quantum architecture to achieve...
# Prediction value: 0.717739
# Positive review detected! With probability of: 0.717738687992096
#
#
# Text: Sofinnova Partners Collaborates with NVIDIA to Accelerate European Life Sciences Startups Sofinnova Partners announced a collaboration with NVIDIA to support its portfolio of life sciences startups. The collaboration delivers significant Graphics Processing Unit credits to select...
# Prediction value: 0.758540
# Positive review detected! With probability of: 0.7585395574569702
#
#
# Text: Dataiku Unveils Enterprise-Grade Blueprint to Accelerate Agentic AI in Financial Services Built with NVIDIA Dataiku announced a new FSI Blueprint for deploying agentic AI systems in financial services. This blueprint is designed to help banking and insurance institutions create, connect, and control...
# Prediction value: 0.704555
# Positive review detected! With probability of: 0.704554557800293
#
#
# Text: Nvidia is going all-in on sovereign AI. Can that help fix its China problem? Nvidia is going all-in on sovereign AI. Can that help fix its China problem?
# Prediction value: 0.678114
# Positive review detected! With probability of: 0.678113579750061
#
#
# Text: Perfect Corp Powers Suite Of Next-Gen Beauty & Fashion Tech Solutions With NVIDIA Accelerated Computing NVIDIA Corp: * PERFECT CORP. POWERS SUITE OF NEXT-GEN BEAUTY & FASHIONTECHSOLUTIONS WITH NVIDIA ACCELERATED COMPUTINGSource text:Further company coverage: ...
# Prediction value: 0.719922
# Positive review detected! With probability of: 0.7199216485023499
#
#
# Text: Dow Jones Futures Fall Amid U.S.-China Trade 'Framework'; Tesla Robotaxi Launch June 22 Dow Jones Futures Fall Amid U.S.-China Trade 'Framework'; Tesla Robotaxi Launch June 22
# Prediction value: 0.717714
# Positive review detected! With probability of: 0.7177143096923828
#
#
# Text: NVIDIA Builds World's First Industrial AI Cloud to Advance European Manufacturing NVIDIA announced it is building the world's first industrial AI cloud for European manufacturers. This Germany-based AI factory will feature 10,000 GPUs, including through NVIDIA DGX?? B200 systems...
# Prediction value: 0.715108
# Positive review detected! With probability of: 0.7151076793670654
#
#
# Text: NVIDIA Corporation to Fuel Region's Next Industrial Transformation NVIDIA GTC Paris at VivaTech--NVIDIA announced it is working with European nations, and technology and industry leaders, to build NVIDIA Blackwell AI infrastructure that will strengthen digital...
# Prediction value: 0.717756
# Positive review detected! With probability of: 0.7177558541297913
#
#
# Text: NVIDIA Partners with Europe Model Builders and Cloud Providers to Accelerate Region?s Leap into AI NVIDIA announced that it is teaming with model builders and cloud providers across Europe and the Middle East to optimize sovereign large language models , providing a springboard to accelerate...
# Prediction value: 0.718065
# Positive review detected! With probability of: 0.7180649042129517
#
#
# Text: Recession Alert: Very Good News For Dividend Stocks A recession could be likely to hit in H2 2025. But this could actually be very good news for dividend stocks. Read how I am positioning my portfolio to benefit from this.
# Prediction value: 0.717331
# Positive review detected! With probability of: 0.7173312306404114
#
#
# Text: France's Mistral Says It Is Introducing Mistral Compute In Partnership With Nvidia NVIDIA Corp: * FRANCE'S MISTRAL SAYS IT IS INTRODUCING MISTRAL COMPUTE INPARTNERSHIP WITH NVIDIASource text:Further company coverage: ...
# Prediction value: 0.719753
# Positive review detected! With probability of: 0.7197527885437012
#
#
# Text: Nvidia CEO Huang Says Nvidia Will Build World's First Industrial AI Cloud In Europe NVIDIA Corp: * NVIDIA CEO HUANG: EUROPE HAS NOW AWAKENED TO THEIMPORTANCE OFAI DATA FACTORIES * HUANG: WE ARE BUILDING AI TECHNOLOGY CENTERS IN SEVENDIFFERENTCOUNTRIES...
# Prediction value: 0.717762
# Positive review detected! With probability of: 0.7177624702453613
